# %%
from bs4 import BeautifulSoup
import urllib2
import pandas as pd

# %%
r = urllib2.urlopen("http://www.indiedb.com/groups/2010-indie-of-the-year-awards/top100").read()
soup = BeautifulSoup(r)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <title>
#    Top 100 - 2010 Indie of the Year Awards - Indie DB
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="top100, 2010 indie of the year awards, event, groups, events, company, club, community, programmers, artists" name="keywords"/>
#   <meta content="Indie of the Year is the largest celebration of hobbyist, amateur and professional Indie developers. With record attendance and a massive number of updates, releases and new projects 2010 was a year like no other, packed to bursting with goodies to make..." name="description"/>
#   <meta content="Top 100 - 2010 Indie of the Year Awards" property="og:title"/>
# ...

# %%
for a in soup.find_all('a', href=True):
    print a['href']
# Out:
# /
# /
# /platforms/set/pc
# /platforms/set/linux
# /platforms/set/mac
# /platforms/set/vr
# /platforms/set/ar
# /platforms/set/iphone
# /platforms/set/android
# /platforms/set/xone
# /platforms/set/ps4
# /platforms/set/wiiu
# /platforms/selection
# /games
# /games
# http://www.slidedb.com
# /games/add
# /downloads
# /downloads
# /addons
# /mods
# /downloads/add
# /videos
# /videos
# /images
# /audio
# /articles
# /reviews
# /headlines
# /articles/add
# /blog
# /rss
# /company
# /company
# /engines
# /jobs
# /jobs/add
# /forum
# /groups
# /forum
# /blogs
# /polls
# /members/register
# /members/register
# http://www.dbolical.com
# http://www.slidedb.com
# http://www.moddb.com
# /members/register
# https://secure.indiedb.com/members/login
# https://secure.indiedb.com/members/loginext/facebook
# https://secure.indiedb.com/members/loginext/twitter
# https://secure.indiedb.com/members/loginext/google
# https://secure.indiedb.com/members/loginext/steam
# ...

# %%
games = soup.find_all('h4')

# %%
for game in games:
    print game.text
# Out:
# Adam's Venture
# Amnesia: The Dark Descent
# BOH
# Minecraft
# Octodad
# Alien Arena
# Bounce!
# FPS Terminator
# Red Alert: A Path Beyond
# SCUD Storm
# Smokin' Guns
# The Ball
# Warsow
# World of Padman
# Zeno Clash
# Zombie Driver
# Din's Curse
# First Fantasy - A Satirical Role Playing Game
# FOnline: 2238
# MoonForge
# AI War: Fleet Command
# AI War: The Zenith Remnant
# Dwarf Fortress
# Gundam RTS
# Star Ruler
# Warzone 2100
# Digitanks
# Gratuitous Space Battles
# UFO: Alien Invasion
# Gang Garrison
# Limbo
# Super Meat Boy
# VVVVVV
# Lemmingball Z
# Mount & Blade: Warband
# Platinum Arts Sandbox Free 3D Game Maker
# Tidalis
# Link-Dead
# Red Crucible
# Steel Storm
# ZEQ2 Lite
# Super Crate Box
# The Line
# Crusader's Quests
# GLiD
# Halo: Out With a Whimper
# Jeklynn Heights
# Overgrowth
# C&C Reborn
# Contagion
# Depth
# Duke Nukem 3D: Reloaded
# E.Y.E
# Interstellar Marines
# Left 4 Quake
# Nazi Zombies: Portable
# Nuclear Dawn
# ORION: Prelude
# OverDose
# Primal Carnage
# ...

# %%
with open('Indie2010.txt', 'w') as f:
    for game in games:
        f.write(game.text.encode('utf8')+"\n")
f.close()

# %% [markdown]
# ## Scrape Steam

# %%
s = urllib2.urlopen("http://store.steampowered.com/tag/en/Indie/#os%5B%5D=mac&p=2&tab=NewReleases").read()
soup_steam = BeautifulSoup(s)

# %%
print soup_steam.prettify()
# Out:
# <!DOCTYPE html>
# <html class=" responsive">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#171a21" name="theme-color"/>
#   <title>
#    Indie games on Steam
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=ful_LJT3NQYl" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=Kb4TtiZh4n2E" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=ZQhT8EbnYTgW" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/css/v6/store.css?v=AMQpDC4ioGJ0" rel="stylesheet" type="text/css"/>
# ...

# %%
#games = soup.find_all('h4')
mydivs = soup_steam.findAll("div", { "class" : "tab_item_name" })

# %%
for game in mydivs:
    print game.text
# Out:
# Invasion
# Undefeated
# Broadside
# ChargeShot
# Timberman
# Shmup Love Boom
# Pumped BMX +
# Moonbase 332
# Defunct
# TY the Tasmanian Tiger 4
# Garry's Mod
# Rust
# Terraria
# The Binding of Isaac: Afterbirth
# Bastion
# Undertale
# SOMA
# TerraTech
# Insurgency
# Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™
# Bastion
# Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™
# Insurgency
# The Long Dark
# White Night
# Tallowmere
# The Binding of Isaac: Afterbirth
# Guild of Dungeoneering
# Greyfox RPG
# SOMA

# %% [markdown]
# ## Scraping  the stored webpages on local drive

# %%
html_data = open("/Users/rohit/Desktop/SteamPowered/page1.html", 'r').read()

# %%
html_soup = BeautifulSoup(html_data)

# %%
print html_soup.prettify()
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0062)http://store.steampowered.com/tag/en/Indie/#p=0&tab=TopSellers -->
# <html class=" responsive">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#171a21" name="theme-color"/>
#   <title>
#    Indie games on Steam
#   </title>
#   <link href="http://store.steampowered.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="./page1_files/motiva_sans.css" rel="stylesheet" type="text/css"/>
#   <link href="./page1_files/shared_global.css" rel="stylesheet" type="text/css"/>
#   <link href="./page1_files/buttons.css" rel="stylesheet" type="text/css"/>
#   <link href="./page1_files/store.css" rel="stylesheet" type="text/css"/>
#   <link href="./page1_files/browse.css" rel="stylesheet" type="text/css"/>
#   <link href="./page1_files/discoveryqueue.css" rel="stylesheet" type="text/css"/>
# ...

# %%
gameNames = html_soup.findAll("div", { "class" : "tab_item_name" })

# %%
for game in gameNames:
    print game.text
# Out:
# Broadside
# Timberman
# Shmup Love Boom
# I Can't Escape: Darkness
# Adventurezator: When Pigs Fly
# PANORAMICAL
# Victor Vran: Tome of Souls Weapon
# Dinosaur Hunt: Africa Contract
# Space Xonix
# Black Closet
# Garry's Mod
# Rust
# Terraria
# The Binding of Isaac: Afterbirth
# Bastion
# Undertale
# SOMA
# TerraTech
# Insurgency
# Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™
# Bastion
# Insurgency
# The Long Dark
# Guild of Dungeoneering
# Frozen Synapse: Complete Pack
# Timberman
# Frozen Synapse: Red DLC
# POSTAL 2
# Sir, You Are Being Hunted
# Infested Planet

# %%
gamelink = html_soup.findAll("a", { "class" : ["tab_item", "tab_item_overlay", "a"]})

# %% [markdown]
# ## Getting Game Names and Game Link

# %%
for i in range(len(gamelink)):
    print "Game: ", gameNames[i].text
    print gamelink[i].get('href')
# Out:
# Game:  Invasion
# http://store.steampowered.com/app/397980/?snr=1_237_querypaginated__103
# Game:  Undefeated
# http://store.steampowered.com/app/332390/?snr=1_237_querypaginated__103
# Game:  Broadside
# http://store.steampowered.com/app/401560/?snr=1_237_querypaginated__103
# Game:  ChargeShot
# http://store.steampowered.com/app/401840/?snr=1_237_querypaginated__103
# Game:  Timberman
# http://store.steampowered.com/app/398710/?snr=1_237_querypaginated__103
# Game:  Shmup Love Boom
# http://store.steampowered.com/app/387110/?snr=1_237_querypaginated__103
# Game:  Pumped BMX +
# http://store.steampowered.com/app/392070/?snr=1_237_querypaginated__103
# Game:  Moonbase 332
# http://store.steampowered.com/app/397580/?snr=1_237_querypaginated__103
# Game:  Defunct
# http://store.steampowered.com/app/359350/?snr=1_237_querypaginated__103
# Game:  TY the Tasmanian Tiger 4
# http://store.steampowered.com/app/287840/?snr=1_237_querypaginated__103
# ...

# %%
len(gameNames)
# Out:
# 30

# %% [markdown]
# ## Checking Page 2

# %%
html_data2 = open("/Users/rohit/Desktop/SteamPowered/page100.html", 'r').read()
html_soup2 = BeautifulSoup(html_data2)

# %%
gameNames = html_soup2.findAll("div", { "class" : "tab_item_name" })
gamelink = html_soup2.findAll("a", { "class" : ["tab_item", "tab_item_overlay", "a"]})
for i in range(len(gamelink)):
    print "Game: ", gameNames[i].text
    print gamelink[i].get('href')
# Out:
# Game:  Invasion
# http://store.steampowered.com/app/397980/?snr=1_237_querypaginated__103
# Game:  Undefeated
# http://store.steampowered.com/app/332390/?snr=1_237_querypaginated__103
# Game:  Broadside
# http://store.steampowered.com/app/401560/?snr=1_237_querypaginated__103
# Game:  ChargeShot
# http://store.steampowered.com/app/401840/?snr=1_237_querypaginated__103
# Game:  Timberman
# http://store.steampowered.com/app/398710/?snr=1_237_querypaginated__103
# Game:  Shmup Love Boom
# http://store.steampowered.com/app/387110/?snr=1_237_querypaginated__103
# Game:  Pumped BMX +
# http://store.steampowered.com/app/392070/?snr=1_237_querypaginated__103
# Game:  Moonbase 332
# http://store.steampowered.com/app/397580/?snr=1_237_querypaginated__103
# Game:  Defunct
# http://store.steampowered.com/app/359350/?snr=1_237_querypaginated__103
# Game:  TY the Tasmanian Tiger 4
# http://store.steampowered.com/app/287840/?snr=1_237_querypaginated__103
# ...

# %% [markdown]
# ## Attempt to get the tags

# %%
OS = html_soup2.findAll("div", { "class" : ["tab_item_details", "platform_img", "top_tag" ]})

# %%
for i in range(10, len(OS)):
    if len(OS[i].text.strip("\n")) <= 1:
        print "NaN"
    else:
        print OS[i].text
# Out:
#  Simulation, Indie, Action, Comedy
#
#
#  Indie, Action, Adventure, Comedy
#
#
#  Tower Defense, Strategy, Local Co-Op, 2D
#
#
#  Rogue-like, Indie, Lovecraftian, First-Person
#
#
#  Early Access, God Game, Indie, Simulation
#
#
#  Action, Indie, Racing
#
#
#  Early Access, Racing, Simulation, Sports
#
# NaN
#
#  Strategy, Adventure, RPG, Indie
#
#
#  Action, Platformer, Indie, Sci-fi
#
#
#  Great Soundtrack, Indie, Action, Narration
#
#
#  FPS, Realistic, Tactical, Action
#
#
#  Early Access, Survival, Open World, First-Person
#
#
#  RPG, Indie, Dungeon Crawler, Card Game
#
# NaN
#
#  Action, Indie, Casual, Multiplayer
#
#
#  Strategy, Indie
#
#
#  Dark Humor, Violent, Action, FPS
#
#
#  Survival, Stealth, Indie, Robots
#
#
#  Strategy, Action, Indie, Top-Down

# %% [markdown]
# ## Getting OS type

# %%
OS = html_soup2.findAll("div", { "class" : ["tab_item_details", "platform_img", "top_tag" ]})

# %%
OS
# Out:
# [<div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Indie</span><span class="top_tag">, Gore</span><span class="top_tag">, Fast-Paced</span></div>
#  </div>, <div class="tab_item_details">
#  <span class="platform_img win"></span> <div class="tab_item_top_tags"><span class="top_tag">Indie</span><span class="top_tag">, RPG</span><span class="top_tag">, Casual</span><span class="top_tag">, JRPG</span></div>
#  </div>, <div class="tab_item_details">
#  <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span><span class="platform_img steamplay"></span> <div class="tab_item_top_tags"><span class="top_tag">Action</span><span class="top_tag">, Adventure</span><span class="top_tag">, Indie</span></div>
#  </div>, <div class="tab_item_details">
# ...

# %%
list = []
for i in OS[10].children:
    list.append(i)

# %%
tag = OS[10].children

# %%
for i in range(1,5):
    a = list[i].attrs
    print a['class'][1]
# Out:
# win
# mac
# linux
# steamplay

# %%
OS[14]
# Out:
# <div class="tab_item_details">
# <span class="platform_img win"></span><span class="platform_img mac"></span><span class="platform_img linux"></span><span class="platform_img steamplay"></span> <div class="tab_item_top_tags"><span class="top_tag">Early Access</span><span class="top_tag">, God Game</span><span class="top_tag">, Indie</span><span class="top_tag">, Simulation</span></div>
# </div>

# %% [markdown]
# ## Putting Everything Together

# %%
html_data3 = open("/Users/rohit/Desktop/SteamPowered/page01.html", 'r').read()
html_soup3 = BeautifulSoup(html_data3)

# %%
gameNames = html_soup3.findAll("div", { "class" : "tab_item_name" })
gamelink = html_soup3.findAll("a", { "class" : ["tab_item", "tab_item_overlay", "a"]})
tags = html_soup3.findAll("div", { "class" : ["tab_item_details", "platform_img", "top_tag" ]})

for i in range(10,20):
    list =[]
    #***********
    # Game Name
    #***********
    print "Game:      ", gameNames[i].text
    
    #**********
    # Game Link
    #**********
    print "Game Link: ", gamelink[i].get('href')
    
    #**********
    # Game Tags
    #**********
    if len(tags[i].text.strip("\n")) <= 1:
        print "NaN"
    else:
        print "Game Tags: ", (tags[i].text).strip(" ")
    
    #*************    
    # Game OS type
    #*************
    oslist = []
    list1 = [z for z in tags[i].children]
    for k in range(1,5):
        try:
            a = list1[k].attrs
            oslist.append(a['class'][1])
        except AttributeError:
            break
    print "Game OSType: ", oslist

    print "*"*70
# Out:
# Game:       Garry's Mod
# Game Link:  http://store.steampowered.com/app/4000/?snr=1_237_querypaginated__104
# Game Tags:
#  Sandbox, Multiplayer, Funny, Moddable
#
# Game OSType:  ['win', 'mac', 'linux', 'steamplay']
# **********************************************************************
# Game:       Rust
# Game Link:  http://store.steampowered.com/app/252490/?snr=1_237_querypaginated__104
# Game Tags:
#  Early Access, Survival, Crafting, Multiplayer
#
# Game OSType:  ['win', 'mac', 'linux', 'steamplay']
# **********************************************************************
# Game:       Terraria
# Game Link:  http://store.steampowered.com/app/105600/?snr=1_237_querypaginated__104
# Game Tags:
#  Sandbox, Adventure, 2D, Crafting
#
# Game OSType:  ['win', 'mac', 'linux', 'steamplay']
# **********************************************************************
# Game:       The Binding of Isaac: Afterbirth
# ...

# %%
#list = []
#for i in tags[10].children:
#    list.append(i)
list1 = [z for z in tags[19].children]
for k in range(1,5):
    try:
        a = list1[k].attrs
        print a['class'][1]
    except AttributeError:
        break
    
#len(list)
# Out:
# win

# %%
OS = html_soup3.findAll("div", { "class" : ["tab_item_details", "platform_img" ]})

# %%
list1 = [k for k in tags[19]]
for i in range(1,5):
    try:
        print list1[i].attrs['class'][1]
    except:
# Out:
#   File "<ipython-input-335-f1453ec45b98>", line 5
#     except:
#            ^
# IndentationError: expected an indented block

# %%
a = list[1].attrs

# %%
list[1].attrs
# Out:
# {'class': ['platform_img', 'win']}

# %% [markdown]
# ## Creating a JSON file

# %%
html_data3 = open("/Users/rohit/Desktop/SteamPowered/page01.html", 'r').read()
html_soup3 = BeautifulSoup(html_data3)

# %%
data = {}
response = []
gameNames = html_soup3.findAll("div", { "class" : "tab_item_name" })
gamelink = html_soup3.findAll("a", { "class" : ["tab_item", "tab_item_overlay", "a"]})
tags = html_soup3.findAll("div", { "class" : ["tab_item_details", "platform_img", "top_tag" ]})

for i in range(10,20):
    
    list =[]
    #***********
    # Game Name
    #***********
    data["Game"] = gameNames[i].text
    
    #**********
    # Game Link
    #**********
    data["Game Link"] = gamelink[i].get('href')
    
    #**********
    # Game Tags
    #**********
    if len(tags[i].text.strip("\n")) <= 1:
        data["GameTags"] =  None
    else:
        data["Game Tags"] = (tags[i].text).strip(" ")
    
    #*************    
    # Game OS type
    #*************
    oslist = []
    list1 = [z for z in tags[i].children]
    for k in range(1,5):
        try:
            a = list1[k].attrs
            oslist.append(a['class'][1])
            data["OSType"] =  a['class'][1]
        except AttributeError:
            break
    data["OSType"] = oslist
    response.append(dict(data))

# %%
print response
# Out:
# [{'OSType': ['win', 'mac', 'linux', 'steamplay'], 'Game': u"Garry's Mod", 'Game Link': 'http://store.steampowered.com/app/4000/?snr=1_237_querypaginated__104', 'Game Tags': u'\n Sandbox, Multiplayer, Funny, Moddable\n'}, {'OSType': ['win', 'mac', 'linux', 'steamplay'], 'Game': u'Rust', 'Game Link': 'http://store.steampowered.com/app/252490/?snr=1_237_querypaginated__104', 'Game Tags': u'\n Early Access, Survival, Crafting, Multiplayer\n'}, {'OSType': ['win', 'mac', 'linux', 'steamplay'], 'Game': u'Terraria', 'Game Link': 'http://store.steampowered.com/app/105600/?snr=1_237_querypaginated__104', 'Game Tags': u'\n Sandbox, Adventure, 2D, Crafting\n'}, {'OSType': ['win', 'mac', 'linux', 'steamplay'], 'Game': u'The Binding of Isaac: Afterbirth', 'Game Link': 'http://store.steampowered.com/app/401920/?snr=1_237_querypaginated__104', 'Game Tags': u'\n Adventure, Action, Rogue-like, Indie\n'}, {'OSType': ['win', 'mac', 'linux', 'steamplay'], 'Game': u'Bastion', 'Game Link': 'http://store.st
# ...

# %%
import json
a = json.dumps(response)

# %%
import pandas as pd

# %%
df = pd.read_json(a)

# %%
df
# Out:
#                                                 Game  \
# 0                                        Garry's Mod
# 1                                               Rust
# 2                                           Terraria
# 3                   The Binding of Isaac: Afterbirth
# 4                                            Bastion
# 5                                          Undertale
# 6                                               SOMA
# 7                                          TerraTech
# 8                                         Insurgency
# 9  Valiant Hearts: The Great War™ / Soldats Incon...
#
#                                            Game Link  \
# 0  http://store.steampowered.com/app/4000/?snr=1_...
# 1  http://store.steampowered.com/app/252490/?snr=...
# 2  http://store.steampowered.com/app/105600/?snr=...
# 3  http://store.steampowered.com/app/401920/?snr=...
# 4  http://store.steampowered.com/app/107100/?snr=...
# 5  http://store.steampowered.com/app/391540/?snr=...
# ...

# %%
df.to_json("test.json")

# %%
df.OSType
# Out:
# 0    [win, mac, linux, steamplay]
# 1    [win, mac, linux, steamplay]
# 2    [win, mac, linux, steamplay]
# 3    [win, mac, linux, steamplay]
# 4    [win, mac, linux, steamplay]
# 5           [win, mac, steamplay]
# 6    [win, mac, linux, steamplay]
# 7    [win, mac, linux, steamplay]
# 8           [win, mac, steamplay]
# 9                           [win]
# Name: OSType, dtype: object

# %%
a = tags[10].text

# %%
a
# Out:
# u'\n Sandbox, Multiplayer, Funny, Moddable\n'

# %%
df['Game Link'][9]
# Out:
# u'http://store.steampowered.com/app/260230/?snr=1_237_querypaginated__104'

# %% [markdown]
# # Part 2: Scraping Steam Game page for Information

# %%
d = urllib2.urlopen("http://www.metacritic.com/game/pc/rust").read()
soup_game = BeautifulSoup(d)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-783f82093917> in <module>()
# ----> 1 d = urllib2.urlopen("http://www.metacritic.com/game/pc/rust").read()
#       2 soup_game = BeautifulSoup(d)
#
# //anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# //anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     435         for processor in self.process_response.get(protocol, []):
#     436             meth = getattr(processor, meth_name)
# --> 437             response = meth(req, response)
#     438
#     439         return response
#
# //anaconda/lib/python2.7/urllib2.pyc in http_response(self, request, response)
# ...

# %%
desc= soup_game.find(attrs={'name':'Description'})
if desc == None:
    desc= soup_game.find(attrs={'name':'description'})
try:
    print desc['content']
except Exception as e:
    print '%s (%s)' % (e.message, type(e))
# Out:
# From the creators of Amnesia: The Dark Descent comes SOMA, a sci-fi horror game set below the waves of the Atlantic ocean. Struggle to survive a hostile world that will make you question your very existence.

# %%
import time
import random
for game_link in df['Game Link']:
    s = urllib2.urlopen(game_link).read()
    soup_link = BeautifulSoup(s)
    desc= soup_link.find(attrs={'name':'Description'})
    if desc == None:
        desc= soup_link.find(attrs={'name':'description'})
    try:
        print desc['content']
    except Exception as e:
        print '%s (%s)' % (e.message, type(e))
    wait_time = random.randint(1,10)
    print "Waiting for...", wait_time
    time.sleep(wait_time)
# Out:
# Garry's Mod is a physics sandbox. There aren't any predefined aims or goals. We give you the tools and leave you to play.
# Waiting for... 1
# The only aim in Rust is to survive. To do this you will need to overcome struggles such as hunger, thirst and cold. Build a fire. Build a shelter. Kill animals for meat. Protect yourself from other players, and kill them for meat. Create alliances with other players and form a town. Whatever it takes to survive.
# Waiting for... 3
# Dig, fight, explore, build! Nothing is impossible in this action-packed adventure game. Four Pack also available!
# Waiting for... 7
# The Binding of Isaac: Rebirth is a randomly generated action RPG shooter with heavy Rogue-like elements. Following Isaac on his journey players will find bizarre treasures that change Isaac’s form giving him super human abilities and enabling him to fight off droves of mysterious creatures, discover secrets and fight his way to safety.
# Waiting for... 5
# ...

# %%
import urllib2, sys

site= "http://www.metacritic.com/game/pc/rust"
#site = "http://store.steampowered.com/app/252490/"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = urllib2.Request(site,headers=hdr)
page = urllib2.urlopen(req)
soup = BeautifulSoup(page)

# %%
gamenames = []
for i in xrange(1,276):
    if i < 10:
        full_url = "/Users/rohit/Desktop/SteamPowered/page0"+str(i)+".html"
    else:
        full_url = "/Users/rohit/Desktop/SteamPowered/page"+str(i)+".html"
    html_data3 = open(full_url, 'r').read()
    html_soup3 = BeautifulSoup(html_data3)
    gameNames = html_soup3.findAll("div", { "class" : "tab_item_name" })
    gamelink = html_soup3.findAll("a", { "class" : ["tab_item", "tab_item_overlay", "a"]})
    for j in range(10,20):
        gamenames.append(gameNames[j].text)

# %%
len(gamenames)
# Out:
# 2750

# %%
gamenames[:10]
# Out:
# [u"Garry's Mod",
#  u'Rust',
#  u'Terraria',
#  u'The Binding of Isaac: Afterbirth',
#  u'Bastion',
#  u'Undertale',
#  u'SOMA',
#  u'TerraTech',
#  u'Insurgency',
#  u'Valiant Hearts: The Great War\u2122 / Soldats Inconnus : M\xe9moires de la Grande Guerre\u2122']

# %% [markdown]
# ## Save unique games

# %%
unique_games = list(set(gamenames))
unique_games.sort()
with open("gameNames.txt", "w") as f:
    for game in unique_games:
        f.write(game.encode('utf8')+"\n")
f.close()

# %%
len(unique_games)
# Out:
# 2396

# %% [markdown]
# ## Trying out Steam Single Games

# %%
game_link = df['Game Link'][9]
s = urllib2.urlopen(game_link).read()
soup_link = BeautifulSoup(s)
print soup_link.prettify()
# Out:
# <!DOCTYPE html>
# <html class=" responsive">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#171a21" name="theme-color"/>
#   <title>
#    Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™ on Steam
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=ful_LJT3NQYl" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=Kb4TtiZh4n2E" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=ZQhT8EbnYTgW" rel="stylesheet" type="text/css"/>
#   <link href="http://store.akamai.steamstatic.com/public/css/v6/store.css?v=AMQpDC4ioGJ0" rel="stylesheet" type="text/css"/>
# ...
